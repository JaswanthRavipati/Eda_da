# %% [markdown]
# <a href="https://colab.research.google.com/github/JaswanthRavipati/Eda_da/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Jaswanth Ravipati")
# Out:
# Jaswanth Ravipati
